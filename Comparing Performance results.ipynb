# %% [markdown]
# # Note : The code will not run without the encodings file (encoding_transfer.pkl) which we can't provide access to anonymously. A link will be provided after the peer review

# %% [markdown]
# # Downloading data

# %%
# !git clone https://github.com/hfawaz/bigdata18.git
# !wget http://supplementarymaterial.xyz/bigdata2018/pre-trained-models.tar.gz
# !tar -xzvf pre-trained-models.tar.gz
# !wget https://www.cs.ucr.edu/~eamonn/time_series_data/UCR_TS_Archive_2015.zip
# !unzip -P attempttoclassify UCR_TS_Archive_2015.zip
# Out:
# Cloning into 'bigdata18'...
# remote: Enumerating objects: 138, done.
# remote: Total 138 (delta 0), reused 0 (delta 0), pack-reused 138
# Receiving objects: 100% (138/138), 3.65 MiB | 7.36 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# --2019-09-03 11:21:53--  http://supplementarymaterial.xyz/bigdata2018/pre-trained-models.tar.gz
# Resolving supplementarymaterial.xyz (supplementarymaterial.xyz)... 213.186.33.19
# Connecting to supplementarymaterial.xyz (supplementarymaterial.xyz)|213.186.33.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260673181 (249M) [application/x-gzip]
# Saving to: ‘pre-trained-models.tar.gz’
#
# pre-trained-models. 100%[===================>] 248.60M  21.1MB/s    in 13s
#
# 2019-09-03 11:22:07 (19.4 MB/s) - ‘pre-trained-models.tar.gz’ saved [260673181/260673181]
#
# UCR_TS_Archive_2015/
# UCR_TS_Archive_2015/BeetleFly/
# UCR_TS_Archive_2015/BeetleFly/history.csv
# UCR_TS_Archive_2015/BeetleFly/df_best_model.csv
# UCR_TS_Archive_2015/BeetleFly/df_metrics.csv
# UCR_TS_Archive_2015/BeetleFly/best_model.hdf5
# UCR_TS_Archive_2015/Fused_datasets/
# UCR_TS_Archive_2015/Fused_datasets/history.csv
# UCR_TS_Archive_2015/Fused_datasets/DONE/
# UCR_TS_Archive_2015/Fused_datasets/df_best_model.csv
# UCR_TS_Archive_2015/Fused_datasets/df_metrics.csv
# UCR_TS_Archive_2015/Fused_datasets/model_init.hdf5
# UCR_TS_Archive_2015/Fused_datasets/best_model.hdf5
# UCR_TS_Archive_2015/ToeSegmentation2/
# UCR_TS_Archive_2015/ToeSegmentation2/history.csv
# UCR_TS_Archive_2015/ToeSegmentation2/df_best_model.csv
# UCR_TS_Archive_2015/ToeSegmentation2/df_metrics.csv
# UCR_TS_Archive_2015/ToeSegmentation2/best_model.hdf5
# UCR_TS_Archive_2015/Haptics/
# UCR_TS_Archive_2015/Haptics/history.csv
# UCR_TS_Archive_2015/Haptics/df_best_model.csv
# UCR_TS_Archive_2015/Haptics/df_metrics.csv
# UCR_TS_Archive_2015/Haptics/best_model.hdf5
# UCR_TS_Archive_2015/ToeSegmentation1/
# UCR_TS_Archive_2015/ToeSegmentation1/history.csv
# UCR_TS_Archive_2015/ToeSegmentation1/df_best_model.csv
# UCR_TS_Archive_2015/ToeSegmentation1/df_metrics.csv
# UCR_TS_Archive_2015/ToeSegmentation1/best_model.hdf5
# UCR_TS_Archive_2015/RefrigerationDevices/
# UCR_TS_Archive_2015/RefrigerationDevices/history.csv
# UCR_TS_Archive_2015/RefrigerationDevices/df_best_model.csv
# UCR_TS_Archive_2015/RefrigerationDevices/df_metrics.csv
# UCR_TS_Archive_2015/Gun_Point/df_best_model.csv
# UCR_TS_Archive_2015/Gun_Point/df_metrics.csv
# UCR_TS_Archive_2015/Gun_Point/best_model.hdf5
# UCR_TS_Archive_2015/50words/
# UCR_TS_Archive_2015/50words/history.csv
# UCR_TS_Archive_2015/50words/df_best_model.csv
# UCR_TS_Archive_2015/50words/df_metrics.csv
# UCR_TS_Archive_2015/50words/best_model.hdf5
# UCR_TS_Archive_2015/ItalyPowerDemand/
# UCR_TS_Archive_2015/ItalyPowerDemand/history.csv
# UCR_TS_Archive_2015/ItalyPowerDemand/df_best_model.csv
# UCR_TS_Archive_2015/ItalyPowerDemand/df_metrics.csv
# UCR_TS_Archive_2015/ItalyPowerDemand/best_model.hdf5
# UCR_TS_Archive_2015/BirdChicken/
# UCR_TS_Archive_2015/BirdChicken/history.csv
# UCR_TS_Archive_2015/BirdChicken/df_best_model.csv
# UCR_TS_Archive_2015/BirdChicken/df_metrics.csv
# UCR_TS_Archive_2015/BirdChicken/best_model.hdf5
# UCR_TS_Archive_2015/DistalPhalanxTW/
# UCR_TS_Archive_2015/DistalPhalanxTW/history.csv
# UCR_TS_Archive_2015/DistalPhalanxTW/df_best_model.csv
# UCR_TS_Archive_2015/DistalPhalanxTW/df_metrics.csv
# UCR_TS_Archive_2015/DistalPhalanxTW/best_model.hdf5
# UCR_TS_Archive_2015/ChlorineConcentration/
# UCR_TS_Archive_2015/ChlorineConcentration/history.csv
# UCR_TS_Archive_2015/ChlorineConcentration/df_best_model.csv
# UCR_TS_Archive_2015/ChlorineConcentration/df_metrics.csv
# UCR_TS_Archive_2015/ChlorineConcentration/best_model.hdf5
# UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/
# UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/history.csv
# UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/df_best_model.csv
# UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/df_metrics.csv
# UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/best_model.hdf5
# --2019-09-03 11:22:13--  https://www.cs.ucr.edu/~eamonn/time_series_data/UCR_TS_Archive_2015.zip
# Resolving www.cs.ucr.edu (www.cs.ucr.edu)... 169.235.30.15
# Connecting to www.cs.ucr.edu (www.cs.ucr.edu)|169.235.30.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126756985 (121M) [application/zip]
# Saving to: ‘UCR_TS_Archive_2015.zip’
#
# UCR_TS_Archive_2015 100%[===================>] 120.88M  76.2MB/s    in 1.6s
#
# 2019-09-03 11:22:15 (76.2 MB/s) - ‘UCR_TS_Archive_2015.zip’ saved [126756985/126756985]
#
# Archive:  UCR_TS_Archive_2015.zip
#   inflating: UCR_TS_Archive_2015/50words/50words_TEST
#   inflating: UCR_TS_Archive_2015/50words/50words_TRAIN
#   inflating: UCR_TS_Archive_2015/Adiac/Adiac_TEST
#   inflating: UCR_TS_Archive_2015/Adiac/Adiac_TRAIN
#   inflating: UCR_TS_Archive_2015/ArrowHead/ArrowHead_TEST
#   inflating: UCR_TS_Archive_2015/ArrowHead/ArrowHead_TRAIN
#   inflating: UCR_TS_Archive_2015/Beef/Beef_TEST
#   inflating: UCR_TS_Archive_2015/Beef/Beef_TRAIN
#   inflating: UCR_TS_Archive_2015/BeetleFly/BeetleFly_TEST
#   inflating: UCR_TS_Archive_2015/BeetleFly/BeetleFly_TRAIN
#   inflating: UCR_TS_Archive_2015/BirdChicken/BirdChicken_TEST
#   inflating: UCR_TS_Archive_2015/FacesUCR/FacesUCR_TRAIN
#   inflating: UCR_TS_Archive_2015/FISH/FISH_TEST
#   inflating: UCR_TS_Archive_2015/FISH/FISH_TRAIN
#   inflating: UCR_TS_Archive_2015/FordA/FordA_TEST
#   inflating: UCR_TS_Archive_2015/FordA/FordA_TRAIN
#   inflating: UCR_TS_Archive_2015/FordB/FordB_TEST
#   inflating: UCR_TS_Archive_2015/FordB/FordB_TRAIN
#   inflating: UCR_TS_Archive_2015/Gun_Point/Gun_Point_TEST
#   inflating: UCR_TS_Archive_2015/Gun_Point/Gun_Point_TRAIN
#   inflating: UCR_TS_Archive_2015/Ham/Ham_TEST
#   inflating: UCR_TS_Archive_2015/Ham/Ham_TRAIN
#   inflating: UCR_TS_Archive_2015/HandOutlines/HandOutlines_TEST
#   inflating: UCR_TS_Archive_2015/HandOutlines/HandOutlines_TRAIN
#   inflating: UCR_TS_Archive_2015/Haptics/Haptics_TEST
#   inflating: UCR_TS_Archive_2015/Haptics/Haptics_TRAIN
#   inflating: UCR_TS_Archive_2015/Herring/Herring_TEST
#   inflating: UCR_TS_Archive_2015/Herring/Herring_TRAIN
#   inflating: UCR_TS_Archive_2015/InlineSkate/InlineSkate_TEST
#   inflating: UCR_TS_Archive_2015/InlineSkate/InlineSkate_TRAIN
#   inflating: UCR_TS_Archive_2015/InsectWingbeatSound/InsectWingbeatSound_TEST
#   inflating: UCR_TS_Archive_2015/InsectWingbeatSound/InsectWingbeatSound_TRAIN
#   inflating: UCR_TS_Archive_2015/ItalyPowerDemand/ItalyPowerDemand_TEST
#   inflating: UCR_TS_Archive_2015/ItalyPowerDemand/ItalyPowerDemand_TRAIN
#   inflating: UCR_TS_Archive_2015/LargeKitchenAppliances/LargeKitchenAppliances_TEST
#   inflating: UCR_TS_Archive_2015/LargeKitchenAppliances/LargeKitchenAppliances_TRAIN
#   inflating: UCR_TS_Archive_2015/Lighting2/Lighting2_TEST
#   inflating: UCR_TS_Archive_2015/Lighting2/Lighting2_TRAIN
#   inflating: UCR_TS_Archive_2015/Lighting7/Lighting7_TEST
#   inflating: UCR_TS_Archive_2015/Lighting7/Lighting7_TRAIN
#   inflating: UCR_TS_Archive_2015/MALLAT/MALLAT_TEST
#   inflating: UCR_TS_Archive_2015/MALLAT/MALLAT_TRAIN
#   inflating: UCR_TS_Archive_2015/Meat/Meat_TEST
#   inflating: UCR_TS_Archive_2015/Meat/Meat_TRAIN
#   inflating: UCR_TS_Archive_2015/MedicalImages/MedicalImages_TEST
#   inflating: UCR_TS_Archive_2015/MedicalImages/MedicalImages_TRAIN
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TEST
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TRAIN
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TEST
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TRAIN
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxTW/MiddlePhalanxTW_TEST
#   inflating: UCR_TS_Archive_2015/MiddlePhalanxTW/MiddlePhalanxTW_TRAIN
#   inflating: UCR_TS_Archive_2015/MoteStrain/MoteStrain_TEST
#   inflating: UCR_TS_Archive_2015/MoteStrain/MoteStrain_TRAIN
#   inflating: UCR_TS_Archive_2015/NonInvasiveFatalECG_Thorax1/NonInvasiveFatalECG_Thorax1_TEST
#   inflating: UCR_TS_Archive_2015/NonInvasiveFatalECG_Thorax1/NonInvasiveFatalECG_Thorax1_TRAIN
#   inflating: UCR_TS_Archive_2015/NonInvasiveFatalECG_Thorax2/NonInvasiveFatalECG_Thorax2_TEST
#   inflating: UCR_TS_Archive_2015/NonInvasiveFatalECG_Thorax2/NonInvasiveFatalECG_Thorax2_TRAIN
#   inflating: UCR_TS_Archive_2015/OliveOil/OliveOil_TEST
#   inflating: UCR_TS_Archive_2015/OliveOil/OliveOil_TRAIN
#   inflating: UCR_TS_Archive_2015/OSULeaf/OSULeaf_TEST
#   inflating: UCR_TS_Archive_2015/OSULeaf/OSULeaf_TRAIN
#   inflating: UCR_TS_Archive_2015/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TEST
#   inflating: UCR_TS_Archive_2015/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TRAIN
#   inflating: UCR_TS_Archive_2015/Phoneme/Phoneme_TEST
#   inflating: UCR_TS_Archive_2015/Phoneme/Phoneme_TRAIN
#   inflating: UCR_TS_Archive_2015/Plane/Plane_TEST
#   inflating: UCR_TS_Archive_2015/Plane/Plane_TRAIN
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TEST
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TRAIN
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TEST
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TRAIN
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxTW/ProximalPhalanxTW_TEST
#   inflating: UCR_TS_Archive_2015/ProximalPhalanxTW/ProximalPhalanxTW_TRAIN
#   inflating: UCR_TS_Archive_2015/RefrigerationDevices/RefrigerationDevices_TEST
#   inflating: UCR_TS_Archive_2015/RefrigerationDevices/RefrigerationDevices_TRAIN
#   inflating: UCR_TS_Archive_2015/ScreenType/ScreenType_TEST
#   inflating: UCR_TS_Archive_2015/ScreenType/ScreenType_TRAIN
#   inflating: UCR_TS_Archive_2015/ShapeletSim/ShapeletSim_TEST
#   inflating: UCR_TS_Archive_2015/ShapeletSim/ShapeletSim_TRAIN
#   inflating: UCR_TS_Archive_2015/ShapesAll/ShapesAll_TEST
#   inflating: UCR_TS_Archive_2015/ShapesAll/ShapesAll_TRAIN
#   inflating: UCR_TS_Archive_2015/SmallKitchenAppliances/SmallKitchenAppliances_TEST
#   inflating: UCR_TS_Archive_2015/SmallKitchenAppliances/SmallKitchenAppliances_TRAIN
#   inflating: UCR_TS_Archive_2015/SonyAIBORobotSurfaceII/SonyAIBORobotSurfaceII_TEST
#   inflating: UCR_TS_Archive_2015/SonyAIBORobotSurfaceII/SonyAIBORobotSurfaceII_TRAIN
#   inflating: UCR_TS_Archive_2015/SonyAIBORobotSurface/SonyAIBORobotSurface_TEST
#   inflating: UCR_TS_Archive_2015/SonyAIBORobotSurface/SonyAIBORobotSurface_TRAIN
#   inflating: UCR_TS_Archive_2015/StarLightCurves/StarLightCurves_TEST
#   inflating: UCR_TS_Archive_2015/StarLightCurves/StarLightCurves_TRAIN
#   inflating: UCR_TS_Archive_2015/Strawberry/Strawberry_TEST
#   inflating: UCR_TS_Archive_2015/Strawberry/Strawberry_TRAIN
#   inflating: UCR_TS_Archive_2015/SwedishLeaf/SwedishLeaf_TEST
#   inflating: UCR_TS_Archive_2015/SwedishLeaf/SwedishLeaf_TRAIN
#   inflating: UCR_TS_Archive_2015/Symbols/Symbols_TEST
#   inflating: UCR_TS_Archive_2015/Symbols/Symbols_TRAIN
#   inflating: UCR_TS_Archive_2015/synthetic_control/synthetic_control_TEST
#   inflating: UCR_TS_Archive_2015/synthetic_control/synthetic_control_TRAIN
#   inflating: UCR_TS_Archive_2015/ToeSegmentation1/ToeSegmentation1_TEST
#   inflating: UCR_TS_Archive_2015/ToeSegmentation1/ToeSegmentation1_TRAIN
#   inflating: UCR_TS_Archive_2015/ToeSegmentation2/ToeSegmentation2_TEST
#   inflating: UCR_TS_Archive_2015/ToeSegmentation2/ToeSegmentation2_TRAIN
#   inflating: UCR_TS_Archive_2015/Trace/Trace_TEST
#   inflating: UCR_TS_Archive_2015/Trace/Trace_TRAIN
#   inflating: UCR_TS_Archive_2015/TwoLeadECG/TwoLeadECG_TEST
#   inflating: UCR_TS_Archive_2015/TwoLeadECG/TwoLeadECG_TRAIN
#   inflating: UCR_TS_Archive_2015/Two_Patterns/Two_Patterns_TEST
#   inflating: UCR_TS_Archive_2015/Two_Patterns/Two_Patterns_TRAIN
#   inflating: UCR_TS_Archive_2015/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TEST
#   inflating: UCR_TS_Archive_2015/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_X/uWaveGestureLibrary_X_TEST
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_X/uWaveGestureLibrary_X_TRAIN
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_Y/uWaveGestureLibrary_Y_TEST
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_Y/uWaveGestureLibrary_Y_TRAIN
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_Z/uWaveGestureLibrary_Z_TEST
#   inflating: UCR_TS_Archive_2015/uWaveGestureLibrary_Z/uWaveGestureLibrary_Z_TRAIN
#   inflating: UCR_TS_Archive_2015/wafer/wafer_TEST
#   inflating: UCR_TS_Archive_2015/wafer/wafer_TRAIN
#   inflating: UCR_TS_Archive_2015/Wine/Wine_TEST
#   inflating: UCR_TS_Archive_2015/Wine/Wine_TRAIN
#   inflating: UCR_TS_Archive_2015/WordsSynonyms/WordsSynonyms_TEST
#   inflating: UCR_TS_Archive_2015/WordsSynonyms/WordsSynonyms_TRAIN
#   inflating: UCR_TS_Archive_2015/WormsTwoClass/WormsTwoClass_TEST
#   inflating: UCR_TS_Archive_2015/WormsTwoClass/WormsTwoClass_TRAIN
#   inflating: UCR_TS_Archive_2015/Worms/Worms_TEST
#   inflating: UCR_TS_Archive_2015/Worms/Worms_TRAIN
#   inflating: UCR_TS_Archive_2015/yoga/yoga_TEST
#   inflating: UCR_TS_Archive_2015/yoga/yoga_TRAIN

# %%
import numpy as np
import pandas as pd
from os import listdir, walk
from os.path import join
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from itertools import product
import pickle
from scipy.stats import spearmanr, pearsonr, kendalltau
from scipy.spatial.distance import cityblock
from scipy.spatial import distance
from scipy.stats import binom_test
from sklearn.metrics import calinski_harabasz_score,silhouette_score, davies_bouldin_score
from sklearn.metrics.pairwise import cosine_distances
from scipy.stats import wilcoxon

# %%
# function to calculate MRR
def mrr(labels, ranking, is_ranked = False):
    if not is_ranked:
        ranking = ranking.argsort(axis=1)
    rr = np.array([1/(np.argwhere(v==ranking[k,:])[0][0]+1) for k, v in enumerate(labels)])
    return rr.mean()
# function to calculate the rank of the optimal source model
def ranks(labels, ranking, is_ranked = False):
    if not is_ranked:
        ranking = ranking.argsort(axis=1)
    ranks = np.array([np.argwhere(v==ranking[k,:])[0][0]+1 for k, v in enumerate(labels)])
    return ranks

# %% [markdown]
# # Reading results from IDS - Fawaz et. al. (https://github.com/hfawaz/bigdata18)

# %%
similarity_lists = pd.read_csv("bigdata18/results/similar_datasets.csv", index_col=0)

sorted_unique_datasets = similarity_lists.index.unique().sort_values()
label_encoder_dict = dict(zip(sorted_unique_datasets.to_list(), range(len(sorted_unique_datasets))))

ranked_similarity_IDS = np.vectorize(label_encoder_dict.get)(similarity_lists)

transfer_results = pd.read_csv("bigdata18/results/df_transfer_acc.csv", index_col=0)

# The paper says that the rows are the source dataset. 
# Since we want to find the best dataset to transfer from we do argmax on the rows.
transfer_results = transfer_results.sort_index(axis=0).sort_index(axis=1)
transfer_results = transfer_results.to_numpy()

best_source = transfer_results.argmax(axis=0)

# %% [markdown]
# # Load encodings from file (the file is large we will upload link after peer-review)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
base_path = "/content/gdrive/My Drive/transfer using encoding/UCR time series transfer"

# %%
load_path = join(base_path, "encoding_transfer.pkl")
with open(load_path, "rb") as file:
    encodings_with_labels= pickle.load(file)

# %% [markdown]
# # Calculate the apriori dissimilarity using MSC with cosine distance

# %%
# may take a few minutes
apriori_dissimilarity = np.ones(encodings_with_labels.shape)*(10**10)
for i in range(encodings_with_labels.shape[0]):
    for j in range(encodings_with_labels.shape[1]):
        if i!=j:
            apriori_dissimilarity[i, j] = -silhouette_score(encodings_with_labels[i, j][0],
                                                            encodings_with_labels[i, j][1], metric="cosine")

# %%
# note that we deleted the transfer of a model to itself because it was set as 0 in the transfer_results file, this could have dramatic effect on results...
transfer_results_without_self_transfer = np.array([np.delete(transfer_results[:,i],i,axis=0) for i in range(transfer_results.shape[1])])
transfer_results_mean_per_target = transfer_results_without_self_transfer.mean(axis=1)

# %%
print("MRR of Random Source Model Selection: ",np.mean(1/(np.arange(84)+1)))
print("MRR of IDS: ", mrr(best_source, ranked_similarity_IDS, is_ranked = True))
print("MRR of our method: ", mrr(best_source, apriori_dissimilarity.T))
# Out:
# MRR of Random Source Model Selection:  0.05969015517363009
# MRR of IDS:  0.11626114810805344
# MRR of our method:  0.11496363721744161

# %%
our_top1_hits = np.sum(transfer_results.argmax(axis=0) == apriori_dissimilarity.T.argmin(axis=1))
IDS_top1_hits = np.sum(transfer_results.argmax(axis=0) == ranked_similarity_IDS[:,0])
N = transfer_results.shape[0]
print("Number of Wins of our method: {}, Accuracy: {:.1f}, P-value: {:.6f}".format(
       our_top1_hits,
      100*our_top1_hits/N,
      binom_test(our_top1_hits,N,1/(N-1))
      ))
print("Number of Wins of IDS: {}, Accuracy: {:.1f}, P-value: {:.6f}".format(
    IDS_top1_hits,
    100*IDS_top1_hits/N,
     binom_test(IDS_top1_hits,N,1/(N-1))
))
print("Number of wins Random: {}, Accuracy: {:.1f}, P-value: {:.6f}".format(
    85*1/(N-1),
    100*1/(N-1),
    binom_test(1,N,1/(N-1))))
# Out:
# Number of Wins of our method: 6, Accuracy: 7.1, P-value: 0.000558
# Number of Wins of IDS: 4, Accuracy: 4.7, P-value: 0.018982
# Number of wins Random: 1.0119047619047619, Accuracy: 1.2, P-value: 1.000000

# %%
ranks_of_best_model_SMS = ranks(best_source, apriori_dissimilarity.T)
ranks_of_best_model_IDS = ranks(best_source, ranked_similarity, is_ranked = True)
print("The difference between our method and IDS isn't statistically significant: " , wilcoxon(ranks_of_best_model_SMS, ranks_of_best_model_IDS))
# Out:
# The difference between our method and IDS isn't statistically significant:  WilcoxonResult(statistic=1519.0, pvalue=0.7655931250772526)

# %% [markdown]
# ## Using other clustering quality metrics

# %%
# helper function for outputting top1 results
def top1stats(apriori_dissimilarity, extra_text):
    our_top1_hits = np.sum(transfer_results.argmax(axis=0) == apriori_dissimilarity.T.argmin(axis=1))
    N = transfer_results.shape[0]
    print("Number of Wins of {}: {}, Accuracy: {:.1f}, P-value: {:.6f}".format(
        extra_text,
        our_top1_hits,
        100*our_top1_hits/N,
        binom_test(our_top1_hits,N,1/(N-1))
        ))

# %% [markdown]
# ### davies_bouldin_score

# %%
apriori_dissimilarity_db = np.ones(encodings_with_labels.shape)*(10**10)
for i in range(encodings_with_labels.shape[0]):
    for j in range(encodings_with_labels.shape[1]):
        if i!=j:
            apriori_dissimilarity_db[i, j] = davies_bouldin_score(encodings_with_labels[i, j][0],
                                                            encodings_with_labels[i, j][1])

# %%
print("MRR of our method with davies_bouldin_score: ", mrr(best_source, apriori_dissimilarity_db.T))
top1stats(apriori_dissimilarity_db, "our method with davies_bouldin_score")
# Out:
# MRR of our method with davies_bouldin_score:  0.09569933999670382
# Number of Wins of our method with davies_bouldin_score: 3, Accuracy: 3.5, P-value: 0.081397

# %% [markdown]
# ### calinski_harabasz_score

# %%
apriori_dissimilarity_vrc = np.ones(encodings_with_labels.shape)*(10**10)
for i in range(encodings_with_labels.shape[0]):
    for j in range(encodings_with_labels.shape[1]):
        if i!=j:
            apriori_dissimilarity_vrc[i, j] = -calinski_harabasz_score(encodings_with_labels[i, j][0],
                                                            encodings_with_labels[i, j][1])

# %%
print("MRR of method with calinski_harabasz_score: ", mrr(best_source, apriori_dissimilarity_vrc.T))
top1stats(apriori_dissimilarity_vrc, "our method with calinski_harabasz_score")
# Out:
# MRR of method with calinski_harabasz_score:  0.06173886810954078
# Number of Wins of our method with calinski_harabasz_score: 2, Accuracy: 2.4, P-value: 0.268642

# %% [markdown]
# ## Using other distance metrics within silhouette

# %%
# may take a few minutes
apriori_dissimilarity_euclidean = np.ones(encodings_with_labels.shape)*(10**10)
for i in range(encodings_with_labels.shape[0]):
    for j in range(encodings_with_labels.shape[1]):
        if i!=j:
            apriori_dissimilarity_euclidean[i, j] = -silhouette_score(encodings_with_labels[i, j][0],
                                                            encodings_with_labels[i, j][1], metric="euclidean")
print("MRR of method with silhouette with euclidean: ", mrr(best_source, apriori_dissimilarity_euclidean.T))
top1stats(apriori_dissimilarity_euclidean, "our method with euclidean")
# Out:
# MRR of method with silhouette with euclidean:  0.10669794129118935
# Number of Wins of our method with euclidean: 5, Accuracy: 5.9, P-value: 0.003567

# %%
# may take a few minutes
apriori_dissimilarity_manhattan = np.ones(encodings_with_labels.shape)*(10**10)
for i in range(encodings_with_labels.shape[0]):
    for j in range(encodings_with_labels.shape[1]):
        if i!=j:
            apriori_dissimilarity_manhattan[i, j] = -silhouette_score(encodings_with_labels[i, j][0],
                                                            encodings_with_labels[i, j][1], metric="manhattan")
print("MRR of method with silhouette with manhattan: ", mrr(best_source, apriori_dissimilarity_manhattan.T))
top1stats(apriori_dissimilarity_manhattan, "our method with manhattan")
# Out:
# MRR of method with silhouette with manhattan:  0.11024946519492677
# Number of Wins of our method with manhattan: 5, Accuracy: 5.9, P-value: 0.003567
